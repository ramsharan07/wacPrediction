# %%
import pandas as pd
import numpy as np
import os
import sys
from wordcloud import WordCloud, STOPWORDS
import collections
import nltk
from nltk.stem import WordNetLemmatizer
  
import re
from nlp_profiler.core import apply_text_profiling

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
import keras
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
#from keras_preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from keras_preprocessing.sequence import pad_sequences
from keras.layers import Input, Dense, LSTM, Embedding
from keras.layers import Dropout, Activation, Bidirectional, GlobalMaxPool1D
from keras.models import Sequential, load_model
from keras import initializers, regularizers, constraints, optimizers, layers
from keras.preprocessing import text, sequence
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from keras.preprocessing import text, sequence
import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Mohan\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Mohan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Mohan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #### Importing data

# %%
fileList = os.listdir('../data')

# %%
data = pd.DataFrame()
for i in fileList:
    data = pd.concat([data, pd.read_excel('../data/'+i)])

# %%
data.reset_index(inplace = True)

# %% [markdown]
# #### Basic summary stats

# %%
data.shape
# Out:
# (4881, 28)

# %%
data.head(2)
# Out:
#    index   OSHPD ID            Manufacturer Name Date Reported   NDC Number  \
# 0      0  Rx0000018  ACADIA Pharmaceuticals Inc.    12/31/2019  63090034030
# 1      1  Rx0000018  ACADIA Pharmaceuticals Inc.    12/31/2019  63090010030
#
#          Drug Product Description WAC Effective Date  WAC Increase Amount  \
# 0  NUPLAZID Oral Capsule 34 MG 30         12/30/2019                155.0
# 1   NUPLAZID Oral Tablet 10 MG 30         12/30/2019                155.0
#
#    WAC After Increase Patent Expiration Date  ... Company Acquired From  \
# 0              3341.0             08/27/2038  ...                   NaN
# 1              3341.0             03/23/2037  ...                   NaN
#
#    Acquisition Price  Acquisition Price Non-Public Indicator  \
# 0                NaN                                     NaN
# 1                NaN                                     NaN
#
#   Acquisition Price Comment  WAC at Acquisition WAC Year Prior to Acquisition  \
# 0                       NaN                 NaN                           NaN
# 1                       NaN                 NaN                           NaN
#
#    Year Drug Introduced to Market WAC at Intro to Market Supporting Documents  \
# 0                             NaN                    NaN                  NaN
# 1                             NaN                    NaN                  NaN
#
#                                     General Comments
# 0  The information contained in this report is su...
# 1  The information contained in this report is su...
#
# [2 rows x 28 columns]

# %%
data.columns
# Out:
# Index(['index', 'OSHPD ID', 'Manufacturer Name', 'Date Reported', 'NDC Number',
#        'Drug Product Description', 'WAC Effective Date', 'WAC Increase Amount',
#        'WAC After Increase', 'Patent Expiration Date', 'Drug Source Type',
#        'Unit Sales Volume in US', 'Unit Sales Volume Non-Public Indicator',
#        'Cost Increase Factors', 'Cost Increase Factors Non-Public Indicator',
#        'Change Improvement Description',
#        'Change Improvement Non-Public Indicator', 'Acquisition Date',
#        'Company Acquired From', 'Acquisition Price',
#        'Acquisition Price Non-Public Indicator', 'Acquisition Price Comment',
#        'WAC at Acquisition', 'WAC Year Prior to Acquisition',
#        'Year Drug Introduced to Market', 'WAC at Intro to Market',
#        'Supporting Documents', 'General Comments'],
#       dtype='object')

# %% [markdown]
# ###### Missing values

# %%
missingDf = pd.DataFrame({'Metric': list(data.isna().sum().index), 'Missing Count': list(data.isna().sum())})
missingDf['Precentage'] = missingDf['Missing Count']*100/data.shape[0]
missingDf.plot(x ='Metric', y='Precentage', kind = 'bar', figsize = (20, 5), color = 'grey')
# Out:
# <AxesSubplot:xlabel='Metric'>

# %%
missingDf
# Out:
#                                         Metric  Missing Count  Precentage
# 0                                        index              0    0.000000
# 1                                     OSHPD ID              0    0.000000
# 2                            Manufacturer Name              0    0.000000
# 3                                Date Reported              0    0.000000
# 4                                   NDC Number              0    0.000000
# 5                     Drug Product Description              0    0.000000
# 6                           WAC Effective Date              0    0.000000
# 7                          WAC Increase Amount              0    0.000000
# 8                           WAC After Increase              0    0.000000
# 9                       Patent Expiration Date           1989   40.749846
# 10                            Drug Source Type              0    0.000000
# 11                     Unit Sales Volume in US           4118   84.367957
# 12      Unit Sales Volume Non-Public Indicator            700   14.341323
# 13                       Cost Increase Factors           3050   62.487195
# 14  Cost Increase Factors Non-Public Indicator           1831   37.512805
# 15              Change Improvement Description           3445   70.579799
# 16     Change Improvement Non-Public Indicator           1733   35.505019
# 17                            Acquisition Date           4282   87.727925
# 18                       Company Acquired From           4282   87.727925
# 19                           Acquisition Price           4622   94.693710
# 20      Acquisition Price Non-Public Indicator           4607   94.386396
# 21                   Acquisition Price Comment           4515   92.501537
# 22                          WAC at Acquisition           4282   87.727925
# 23               WAC Year Prior to Acquisition           4426   90.678140
# 24              Year Drug Introduced to Market           4282   87.727925
# 25                      WAC at Intro to Market           4283   87.748412
# 26                        Supporting Documents           4524   92.685925
# 27                            General Comments           1314   26.920713

# %% [markdown]
# ###### Key Stats - Describe

# %%
data.describe(include = 'all')
# Out:
#               index   OSHPD ID Manufacturer Name Date Reported    NDC Number  \
# count   4881.000000       4881              4881          4881  4.881000e+03
# unique          NaN        224               227            16           NaN
# top             NaN  Rx0000020          Allergan    03/31/2019           NaN
# freq            NaN        317               317          1108           NaN
# mean     617.050604        NaN               NaN           NaN  3.458457e+10
# std      364.757413        NaN               NaN           NaN  2.904955e+10
# min        0.000000        NaN               NaN           NaN  2.143380e+06
# 25%      305.000000        NaN               NaN           NaN  4.096648e+08
# 50%      610.000000        NaN               NaN           NaN  4.420605e+10
# 75%      915.000000        NaN               NaN           NaN  6.195807e+10
# max     1404.000000        NaN               NaN           NaN  8.212001e+10
#
#                             Drug Product Description WAC Effective Date  \
# count                                           4881               4881
# unique                                          3683                324
# top     LEU TechneLite® (Technetium Tc99m Generator)         01/01/2019
# freq                                              13                562
# mean                                             NaN                NaN
# std                                              NaN                NaN
# min                                              NaN                NaN
# 25%                                              NaN                NaN
# 50%                                              NaN                NaN
# 75%                                              NaN                NaN
# max                                              NaN                NaN
#
#         WAC Increase Amount  WAC After Increase Patent Expiration Date  ...  \
# count           4881.000000         4881.000000                   2892  ...
# unique                  NaN                 NaN                    514  ...
# top                     NaN                 NaN             10/19/2037  ...
# freq                    NaN                 NaN                     50  ...
# mean             222.915249         3496.203307                    NaN  ...
# std              779.681737         8327.335201                    NaN  ...
# min                0.030000           13.690000                    NaN  ...
# 25%               22.990000          369.060000                    NaN  ...
# 50%               55.210000          818.970000                    NaN  ...
# 75%              175.860000         2555.890000                    NaN  ...
# max            34664.000000       154000.000000                    NaN  ...
#
#        Company Acquired From  Acquisition Price  \
# count                    599       2.590000e+02
# unique                   110                NaN
# top                    IMPAX                NaN
# freq                      54                NaN
# mean                     NaN       1.093140e+09
# std                      NaN       3.240078e+09
# min                      NaN       0.000000e+00
# 25%                      NaN       1.750000e+07
# 50%                      NaN       8.700000e+07
# 75%                      NaN       3.110000e+08
# max                      NaN       1.340000e+10
#
#         Acquisition Price Non-Public Indicator  \
# count                                    274.0
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                       1.0
# std                                        0.0
# min                                        1.0
# 25%                                        1.0
# 50%                                        1.0
# 75%                                        1.0
# max                                        1.0
#
#                                 Acquisition Price Comment  WAC at Acquisition  \
# count                                                 366          599.000000
# unique                                                 93                 NaN
# top     This deal was a merger in which Impax sharehol...                 NaN
# freq                                                   55                 NaN
# mean                                                  NaN         2743.837112
# std                                                   NaN         5244.623715
# min                                                   NaN            1.000000
# 25%                                                   NaN          307.700000
# 50%                                                   NaN          607.850000
# 75%                                                   NaN         3286.555000
# max                                                   NaN        49949.210000
#
#        WAC Year Prior to Acquisition  Year Drug Introduced to Market  \
# count                     455.000000                      599.000000
# unique                           NaN                             NaN
# top                              NaN                             NaN
# freq                             NaN                             NaN
# mean                     2063.558242                     2011.490818
# std                      3907.781999                        7.980295
# min                         0.000000                     1961.000000
# 25%                       227.115000                     2010.000000
# 50%                       500.000000                     2014.000000
# 75%                      1271.390000                     2015.000000
# max                     40492.980000                     2022.000000
#
#        WAC at Intro to Market  \
# count               598.00000
# unique                    NaN
# top                       NaN
# freq                      NaN
# mean               2216.83408
# std                4428.27829
# min                   0.01000
# 25%                 198.78250
# 50%                 402.09000
# 75%                1875.00000
# max               40068.00000
#
#                                      Supporting Documents  \
# count                                                 357
# unique                                                357
# top     https://reports.siera.oshpd.ca.gov/api/report/...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                          General Comments
# count                                                3567
# unique                                                557
# top     For Column F as reflected in the FDA publicati...
# freq                                                  174
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
# [11 rows x 28 columns]

# %%
data.columns
# Out:
# Index(['index', 'OSHPD ID', 'Manufacturer Name', 'Date Reported', 'NDC Number',
#        'Drug Product Description', 'WAC Effective Date', 'WAC Increase Amount',
#        'WAC After Increase', 'Patent Expiration Date', 'Drug Source Type',
#        'Unit Sales Volume in US', 'Unit Sales Volume Non-Public Indicator',
#        'Cost Increase Factors', 'Cost Increase Factors Non-Public Indicator',
#        'Change Improvement Description',
#        'Change Improvement Non-Public Indicator', 'Acquisition Date',
#        'Company Acquired From', 'Acquisition Price',
#        'Acquisition Price Non-Public Indicator', 'Acquisition Price Comment',
#        'WAC at Acquisition', 'WAC Year Prior to Acquisition',
#        'Year Drug Introduced to Market', 'WAC at Intro to Market',
#        'Supporting Documents', 'General Comments'],
#       dtype='object')

# %%
data.groupby(['Manufacturer Name'], as_index = False).count()[['Manufacturer Name', 'Drug Product Description']].sort_values(['Drug Product Description'], ascending = False).head(100)
# Out:
#             Manufacturer Name  Drug Product Description
# 19                   Allergan                       317
# 162                    Pfizer                       290
# 52       Boehringer Ingelheim                       278
# 149                  Novartis                       245
# 202  Teva Pharmaceuticals USA                       187
# ..                        ...                       ...
# 88      Galderma Laboratories                        11
# 128      MILLICENT U.S., INC.                        11
# 132      MannKind Corporation                        11
# 179       SUN PHARMACEUTICALS                        10
# 191                  Shire US                        10
#
# [100 rows x 2 columns]

# %%
data.groupby(['Drug Product Description'], as_index = False).count()[['Drug Product Description', 'Manufacturer Name']].sort_values(['Manufacturer Name'], ascending = False)
# Out:
#                                Drug Product Description  Manufacturer Name
# 3168           TechneLite® (Technetium Tc99m Generator)                 13
# 1817       LEU TechneLite® (Technetium Tc99m Generator)                 13
# 230   ADCETRIS, 50mg, single-dose vial, packaged singly                  8
# 1122                            Entyvio 300mg 20mL Vial                  6
# 3634  ferumoxytol 510MG/17 mL  Feraheme 510mg/17 mL ...                  6
# ...                                                 ...                ...
# 1393  Gonal-f RFF Rediject Subcutaneous Solution 300...                  1
# 1394  Gonal-f RFF Rediject Subcutaneous Solution 450...                  1
# 1395  Gonal-f RFF Rediject Subcutaneous Solution 900...                  1
# 1396  Gonal-f RFF Subcutaneous Solution Reconstitute...                  1
# 3682  oxyMORphone HCl ER Oral Tablet Extended Releas...                  1
#
# [3683 rows x 2 columns]

# %%
data[data['Drug Product Description'].str.lower().str.contains('cosentyx')].to_excel('../outputs/cosentyx.xlsx')

# %%
data['Drug Product Description'].str.contains('drg')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4876    False
# 4877    False
# 4878    False
# 4879    False
# 4880    False
# Name: Drug Product Description, Length: 4881, dtype: bool

# %%
data.columns
# Out:
# Index(['index', 'OSHPD ID', 'Manufacturer Name', 'Date Reported', 'NDC Number',
#        'Drug Product Description', 'WAC Effective Date', 'WAC Increase Amount',
#        'WAC After Increase', 'Patent Expiration Date', 'Drug Source Type',
#        'Unit Sales Volume in US', 'Unit Sales Volume Non-Public Indicator',
#        'Cost Increase Factors', 'Cost Increase Factors Non-Public Indicator',
#        'Change Improvement Description',
#        'Change Improvement Non-Public Indicator', 'Acquisition Date',
#        'Company Acquired From', 'Acquisition Price',
#        'Acquisition Price Non-Public Indicator', 'Acquisition Price Comment',
#        'WAC at Acquisition', 'WAC Year Prior to Acquisition',
#        'Year Drug Introduced to Market', 'WAC at Intro to Market',
#        'Supporting Documents', 'General Comments'],
#       dtype='object')

# %%
data.groupby(['Drug Source Type'], as_index = False).count()[['Drug Source Type', 'Manufacturer Name']].sort_values(['Manufacturer Name'], ascending = False)
# Out:
#                      Drug Source Type  Manufacturer Name
# 2                  Single Source Drug               3119
# 0      Innovator Multiple Source Drug                964
# 1  Non-innovator Multiple Source Drug                798

# %% [markdown]
# ###### Checking duplicates

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###### Analyzing WAC fields

# %%
data.columns
# Out:
# Index(['index', 'OSHPD ID', 'Manufacturer Name', 'Date Reported', 'NDC Number',
#        'Drug Product Description', 'WAC Effective Date', 'WAC Increase Amount',
#        'WAC After Increase', 'Patent Expiration Date', 'Drug Source Type',
#        'Unit Sales Volume in US', 'Unit Sales Volume Non-Public Indicator',
#        'Cost Increase Factors', 'Cost Increase Factors Non-Public Indicator',
#        'Change Improvement Description',
#        'Change Improvement Non-Public Indicator', 'Acquisition Date',
#        'Company Acquired From', 'Acquisition Price',
#        'Acquisition Price Non-Public Indicator', 'Acquisition Price Comment',
#        'WAC at Acquisition', 'WAC Year Prior to Acquisition',
#        'Year Drug Introduced to Market', 'WAC at Intro to Market',
#        'Supporting Documents', 'General Comments'],
#       dtype='object')

# %%
data['WAC Prec Increase'] = data['WAC Increase Amount']/(data['WAC After Increase']+data['WAC Increase Amount'])
data['WAC Before Increase'] = data['WAC After Increase'] - data['WAC Increase Amount']

# %%
data[data['WAC Increase Amount'] <= 5000]['WAC Prec Increase'].plot.hist(bins = 50, color='grey')
plt.title('WAC Prec Increase - Histogram')
plt.show()

# %%
data[data['WAC Increase Amount'] <= 5000]['WAC Before Increase'].plot.hist(bins = 50, color='grey')
plt.title('WAC Before Increase - Histogram')
plt.show()

# %%
data[data['WAC Increase Amount'] <= 5000].plot(x = 'WAC Prec Increase', y = 'WAC Before Increase', kind = 'scatter', color= 'grey', figsize=(20, 5))
plt.title('WAC After Increase % vs WAC Price Before Increase')
plt.show()

# %% [markdown]
# ###### Analyzing cost increase factor

# %%
textData = ''.join(list(data[~data['Cost Increase Factors'].isna()]['Cost Increase Factors'].to_string()))

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = set(STOPWORDS),
                min_font_size = 10).generate(textData)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

# %% [markdown]
# - Mssing values with Nan and product names are forming majority of the text this need to be addressed during datapre

# %% [markdown]
# ###### Checking frequent word distribution

# %%
data['Cost Increase Factors']
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2       AMPYRA® has not been reformulated, but AMPYRA®...
# 3                                                     NaN
# 4                                                     NaN
#                               ...
# 4876    Our pricing is guided by the value our product...
# 4877    Our pricing is guided by the value our product...
# 4878    Our pricing is guided by the value our product...
# 4879    Our pricing is guided by the value our product...
# 4880    Our pricing is guided by the value our product...
# Name: Cost Increase Factors, Length: 4881, dtype: object

# %%
str(data['Drug Product Description'][2]).split(' ')[0].lower()
# Out:
# 'ampyra'

# %%
##### Replacing drug names from description
wordList = []

for i, j in zip(data[~data['Cost Increase Factors'].isna()]['Cost Increase Factors'], data[~data['Cost Increase Factors'].isna()]['Drug Product Description']):
    wordList.extend(str(i).lower().replace(str(j).split(' ')[0].lower(), '').split(' '))

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = set(STOPWORDS.union(set(['nan']))),
                min_font_size = 10).generate(' '.join(wordList))
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

# %% [markdown]
# ###### Top frequent words

# %%
counter=collections.Counter(wordList)
most=counter.most_common()

x, y= [], []
for word,count in most[:30]:
    if (word not in set(STOPWORDS.union(set(['nan', ''])))):
        x.append(word)
        y.append(count)

sns.barplot(x=y,y=x)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### Observing frequent bigrams

# %%
counter=collections.Counter(nltk.bigrams(wordList))

### Bigram df
w1 = []
w2 = []
value = [] 
for i,j in zip(list(counter), list(counter.values())) :
    w1.append(i[0])
    w2.append(i[1])
    value.append(j)

bigramDf = pd.DataFrame({'word1': w1, 'word2': w2, 'freq': value}).sort_values(['freq'], ascending = False)

# %%
bigramDf.head()
# Out:
#          word1 word2   freq
# 675                   30346
# 219         in   the    711
# 23        cost    of    615
# 2330        of     a    601
# 2296  continue    to    590

# %%
#bigramDf.to_excel('../outputs/EDA Report/bigram.xlsx')

# %% [markdown]
# ###### Observing frequent tri-grams

# %%
### Trigrams df
w1 = []
w2 = []
w3 = []
value = [] 
counter=collections.Counter(nltk.trigrams(wordList))
for i,j in zip(list(counter), list(counter.values())) :
    w1.append(i[0])
    w2.append(i[1])
    w3.append(i[2])
    value.append(j)

trigramDf = pd.DataFrame({'word1': w1, 'word2': w2, 'word2': w3, 'freq': value}).sort_values(['freq'], ascending = False)

# %%
#trigramDf.to_excel('../outputs/EDA Report/trigram.xlsx')

# %%
trigramDf.head()
# Out:
#          word1        word2   freq
# 720                          29953
# 998   research  development    525
# 1205       the           of    400
# 603     ensure       access    396
# 2794        to      patient    390

# %% [markdown]
# ###### Defining class for Text preprocessing

# %%
class textPreprocessing():
    '''
    Class takes text as input and return processed text post all data cleaning steps
    '''
    def __init__(self, text, dgName):
        self.procText = text
        self.drugName = dgName
       
    ## Module for text normalization
    def textNormalization(self):
        self.procText = self.procText.lower()
        
    ## Module for removing unwanted spaces
    def stripSpaces(self):
        self.procText = self.procText.strip()
    
    ## Module for stopwords removal
    def stopwordRemoval(self):
        self.procText = ' '.join([i for i in self.procText.split(' ') if i not in STOPWORDS])
        
    ## Module for removing special characters
    def specialCharRemoval(self):
        specialWords = ['.', ',', "'", '?', '-', '_', '+', '$', '®', '™', '(', ')']
        
        self.procText = ' '.join([re.sub("[^A-Z]", "", i,0,re.IGNORECASE) for i in self.procText.split(' ')])
        #for i in specialWords:
            #self.procText = re.sub(''+i, '', self.procText)
            
            
              
            
    ## Module for drug names from text
    def drugNameRemoval(self):
        #print(str(self.drugName).split(' ')[0].lower())
        #print(self.procText.replace(str(self.drugName).split(' ')[0].lower(), ''))
        self.procText = ' '.join(self.procText.replace(str(self.drugName).split(' ')[0].lower(), '').split(' '))
    
    ## Module for wordLemmatization
    def rootExtLemmatization(self):
        self.procText = ' '.join([WordNetLemmatizer().lemmatize(i) for i in self.procText.split(' ')])
    
    ## Module for call all preprocessing steps
    def all(self):
        self.textNormalization()

        self.stopwordRemoval()
        self.specialCharRemoval()
        self.drugNameRemoval()
        self.rootExtLemmatization()
        self.stripSpaces()
        return self.procText

# %% [markdown]
# ###### Removing missing values

# %%
dataUpdated = data[~data['Cost Increase Factors'].isna()]
dataUpdated.reset_index(inplace = True)

# %% [markdown]
# ###### Preprocessing

# %%
dataUpdated['Cost Increase Factors_Updated'] = [str(textPreprocessing(str(i), str(j)).all()) for i,j in zip(dataUpdated['Cost Increase Factors'], dataUpdated['Drug Product Description'])]

# %%
dataUpdated['Cost Increase Factors_Updated'][0:5][0]
# Out:
# 'reformulated  manufacturer primary source revenue revenue recentlyapproved product inbrija increase'

# %%
dataUpdated['Cost Increase Factors'][0:5][0]
# Out:
# "AMPYRA® has not been reformulated, but AMPYRA® is the manufacturer's primary source of revenue while revenue from a more recently-approved product, INBRIJA™, increases."

# %%
### Exclude columns with greater than 30% missing values

# %%
##### Replacing drug names from description
wordListProcessed = " ".join(dataUpdated['Cost Increase Factors_Updated'])

# %%
counter=collections.Counter(nltk.bigrams(wordListProcessed.split(' ')))
### Bigram df
w1 = []
w2 = []
value = [] 
for i,j in zip(list(counter), list(counter.values())) :
    w1.append(i[0])
    w2.append(i[1])
    value.append(j)

bigramDf = pd.DataFrame({'word1': w1, 'word2': w2, 'freq': value}).sort_values(['freq'], ascending = False)

# %%
bigramDf
# Out:
#             word1        word2   freq
# 58                              26759
# 366        market      dynamic    598
# 593      research  development    537
# 283        market    condition    512
# 353       patient       access    503
# ...           ...          ...    ...
# 3017  consistency      current      1
# 3018       market       market      1
# 3019       market        share      1
# 3020        share  determining      1
# 3957          fee      pricing      1
#
# [3958 rows x 3 columns]

# %%
#bigramDf.to_excel('../outputs/EDA Report/bigram.xlsx')

# %%
### Trigrams df
w1 = []
w2 = []
w3 = []
value = [] 
counter=collections.Counter(nltk.trigrams(wordListProcessed.split(' ')))
for i,j in zip(list(counter), list(counter.values())) :
    w1.append(i[0])
    w2.append(i[1])
    w3.append(i[2])
    value.append(j)

trigramDf = pd.DataFrame({'word1': w1, 'word2': w2, 'word3': w3, 'freq': value}).sort_values(['freq'], ascending = False)

# %%
#trigramDf.to_excel('../outputs/EDA Report/trigram.xlsx')

# %%
trigramDf
# Out:
#            word1        word2          word3   freq
# 467                                           26192
# 380       ensure      patient         access    403
# 1488    clinical     economic          value    357
# 863     research  development           cost    347
# 1768  determined      careful  consideration    335
# ...          ...          ...            ...    ...
# 3705  regulation         pbms    recognizing      1
# 3704     service   regulation           pbms      1
# 3703  preventive      service     regulation      1
# 3702         aca   preventive        service      1
# 5038         fee      pricing         guided      1
#
# [5039 rows x 4 columns]

# %%
#dataUpdated.to_csv('../outputs/cleanedText.csv')

# %%
counter=collections.Counter(wordListProcessed.split(' '))
most=counter.most_common()

# x, y= [], []
# for word,count in most[:30]:
#     if (word not in set(STOPWORDS.union(set(['nan', ''])))):
#         x.append(word)
#         y.append(count)

# sns.barplot(x=y,y=x)

# %% [markdown]
# ###### Feature Engineering

# %%
np.isnan(dataUpdated['WAC Prec Increase']).sum()
# Out:
# 0

# %%
textFeature = dataUpdated['Cost Increase Factors_Updated']
target = dataUpdated['WAC Prec Increase']

X_train, X_test, y_train, y_test = train_test_split(textFeature, target, test_size=0.2, random_state=2)

# %%
tkn = Tokenizer(num_words=2000)
tkn.fit_on_texts(textFeature)
X_trainTok = tkn.texts_to_sequences(X_train)
X_testTok = tkn.texts_to_sequences(X_test)

# %%
maxlen = 100

X_trainTok = pad_sequences(X_trainTok, padding='post', maxlen=maxlen)
X_testTok = pad_sequences(X_testTok, padding='post', maxlen=maxlen)

# %% [markdown]
# ###### Model Development

# %% [markdown]
# - MLP Model

# %%
model = Sequential()
model.add(Dense(1024, input_shape=(X_trainTok.shape[1],), activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_absolute_error', optimizer='adam')

# %%
model.fit(X_trainTok, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 147/147 [==============================] - 2s 5ms/step - loss: 0.1332
# Epoch 2/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 3/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 4/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 5/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 6/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0421
# Epoch 7/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0421
# Epoch 8/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 9/150
# 147/147 [==============================] - 1s 7ms/step - loss: 0.0420
# Epoch 10/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0422
# Epoch 11/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0421
# Epoch 12/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 13/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 14/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 15/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 16/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 17/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 18/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 19/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 20/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 21/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 22/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 23/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 24/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 25/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 26/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 27/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 28/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 29/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 30/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0421
# Epoch 31/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 32/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 33/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 34/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 35/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 36/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0421
# Epoch 37/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 38/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 39/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0421
# Epoch 40/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 41/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 42/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 43/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 44/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 45/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 46/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 47/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 48/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 49/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0421
# Epoch 50/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0421
# Epoch 51/150
# 147/147 [==============================] - 1s 7ms/step - loss: 0.0421
# Epoch 52/150
# 147/147 [==============================] - 1s 7ms/step - loss: 0.0421
# Epoch 53/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 54/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 55/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 56/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 57/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 58/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0420
# Epoch 59/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 60/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 61/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 62/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 63/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 64/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0421
# Epoch 65/150
# 147/147 [==============================] - 1s 6ms/step - loss: 0.0420
# Epoch 66/150
# 147/147 [==============================] - 1s 5ms/step - loss: 0.0421
# Epoch 67/150
#  40/147 [=======>......................] - ETA: 0s - loss: 0.0508
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 model.fit(X_trainTok, y_train, epochs=150, batch_size=10)
#
# File F:\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File F:\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File F:\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File F:\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File F:\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File F:\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File F:\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File F:\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File F:\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
# Out:
# 46/46 [==============================] - 1s 2ms/step
# array([[0.05323203],
#        [0.05323203],
#        [0.05323203],
#        ...,
#        [0.05323203],
#        [0.05323203],
#        [0.05323203]], dtype=float32)

# %% [markdown]
# - Error Calculation

# %%
trainDf = pd.DataFrame({'Actual': y_train, 'Predicted': [i[0] for i in model.predict(X_trainTok)]})
trainDf['Error Prec'] = np.abs(trainDf['Actual'] - trainDf['Predicted'])/trainDf['Actual']
trainMape = np.mean(trainDf['Error Prec'])

testDf = pd.DataFrame({'Actual': y_test, 'Predicted': [i[0] for i in model.predict(X_testTok)]})
testDf['Error Prec'] = np.abs(testDf['Actual'] - testDf['Predicted'])/testDf['Actual']
testMape = np.mean(testDf['Error Prec'])

print("Train Error %s"%(trainMape))
print("Test Error %s"%(testMape))
# Out:
# 46/46 [==============================] - 0s 2ms/step
# 12/12 [==============================] - 0s 3ms/step
# Train Error 0.4808374368085169
# Test Error 0.4365288196856697

# %% [markdown]
# - Model iteration on different epochs

# %%
def modelEpochs(ep):
    print(('Epoch - %s'%(ep)))
    model = Sequential()
    model.add(Dense(1024, input_shape=(X_trainTok.shape[1],), activation='relu'))
    #model.add(Dense(512, activation='relu'))
    model.add(Dense(256, activation='relu'))
   # model.add(Dense(64, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_absolute_error', optimizer='adam')
    
    model.fit(X_trainTok, y_train, epochs=ep, batch_size=10, verbose=0)
    
    trainDf = pd.DataFrame({'Actual': y_train, 'Predicted': [i[0] for i in model.predict(X_trainTok, verbose=0)]})
    trainDf['Error Prec'] = np.abs(trainDf['Actual'] - trainDf['Predicted'])/trainDf['Actual']
    trainMape = np.mean(trainDf['Error Prec'])

    testDf = pd.DataFrame({'Actual': y_test, 'Predicted': [i[0] for i in model.predict(X_testTok, verbose=0)]})
    testDf['Error Prec'] = np.abs(testDf['Actual'] - testDf['Predicted'])/testDf['Actual']
    testMape = np.mean(testDf['Error Prec'])

    return ep, trainMape, testMape

# %%
epList = []
taMapeList = []
teMapeList =  []
for i in range(1, 50, 2):
    ep, taMape, teMape = modelEpochs(i)
    epList.append(ep)
    taMapeList.append(taMape)
    teMapeList.append(teMape)
# Out:
# Epoch - 1
# Epoch - 3
# Epoch - 5
# Epoch - 7
# Epoch - 9
# Epoch - 11
# Epoch - 13
# Epoch - 15
# Epoch - 17
# Epoch - 19
# Epoch - 21
# Epoch - 23
# Epoch - 25
# Epoch - 27
# Epoch - 29
# Epoch - 31
# Epoch - 33
# Epoch - 35
# Epoch - 37
# Epoch - 39
# Epoch - 41
# Epoch - 43
# Epoch - 45
# Epoch - 47
# Epoch - 49

# %%
pd.DataFrame({'Epoch': epList, 'Train MAPE': taMapeList, 'Test MAPE': teMapeList})
# Out:
#     Epoch  Train MAPE  Test MAPE
# 0       1    0.484986   0.440361
# 1       3    0.514593   0.467854
# 2       5    0.458077   0.415482
# 3       7    0.482330   0.437919
# 4       9    0.466635   0.423265
# 5      11    0.493150   0.447764
# 6      13    0.472678   0.428914
# 7      15    0.496730   0.451022
# 8      17    0.482205   0.437802
# 9      19    0.473005   0.429219
# 10     21    0.473996   0.430146
# 11     23    0.480681   0.436383
# 12     25    0.496951   0.451223
# 13     27    0.482297   0.437888
# 14     29    0.470407   0.426791
# 15     31    0.495101   0.449537
# 16     33    0.490639   0.445481
# 17     35    0.481809   0.437433
# 18     37    0.500518   0.454482
# 19     39    0.481489   0.437135
# 20     41    0.492031   0.446747
# 21     43    0.480097   0.435840
# 22     45    0.484972   0.440348
# 23     47    0.481039   0.436716
# 24     49    0.481677   0.437311

# %%
pd.DataFrame({'Epoch': epList, 'Train MAPE': taMapeList, 'Test MAPE': teMapeList}).to_csv('../outputs/Data Preparation and Initial Model Report/Error_vs_Epochs.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 pd.DataFrame({'Epoch': epList, 'Train MAPE': taMapeList, 'Test MAPE': teMapeList}).to_csv('../outputs/Data Preparation and Initial Model Report/Error_vs_Epochs.csv')
#
# NameError: name 'epList' is not defined

# %% [markdown]
# ### Building RNN model

# %% [markdown]
# - Data Preparatin for RNN

# %%
vocab = set(word.lower() for script in textFeature for word in script.split(' '))

# %%
len(vocab)
# Out:
# 1323

# %%
wordTknr = text.Tokenizer(num_words=10000)
wordTknr.fit_on_texts(list(textFeature))
tokenized_texts = wordTknr.texts_to_sequences(textFeature)
X = pad_sequences(tokenized_texts, maxlen=300)

X_train, X_test, y_train, y_test = train_test_split(X, target, test_size=0.2, random_state=2)

# %%
import pickle

# saving
with open('../models/tokenizer.pickle', 'wb') as handle:
    pickle.dump(wordTknr, handle, protocol=pickle.HIGHEST_PROTOCOL)

# loading
with open('../models/tokenizer.pickle', 'rb') as handle:
    wordTknr = pickle.load(handle)

# %%
# create my NN model
wacRNNModel = Sequential()

embedding_size = 80
wacRNNModel.add(Embedding(len(vocab), embedding_size))
wacRNNModel.add(LSTM(20, return_sequences=True))
wacRNNModel.add(GlobalMaxPool1D())
wacRNNModel.add(Dense(10, activation='relu'))
wacRNNModel.add(Dense(5, activation='relu'))
wacRNNModel.add(Dense(1, activation='linear')) 

wacRNNModel.compile(loss='mse', 
              optimizer='adam', 
              metrics=['mse'])
wacRNNModel.summary()


epc = 60
wacRNNModel.fit(X_train, y_train, epochs=epc, batch_size=32)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, None, 80)          105840
#
#  lstm_7 (LSTM)               (None, None, 20)          8080
#
#  global_max_pooling1d_7 (Glo  (None, 20)               0
#  balMaxPooling1D)
#
#  dense_21 (Dense)            (None, 10)                210
#
#  dense_22 (Dense)            (None, 5)                 55
#
#  dense_23 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 114,191
# Trainable params: 114,191
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 46/46 [==============================] - 5s 72ms/step - loss: 0.0042 - mse: 0.0042
# Epoch 2/60
# 46/46 [==============================] - 3s 75ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 3/60
# 46/46 [==============================] - 3s 75ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 4/60
# 46/46 [==============================] - 4s 76ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 5/60
# 46/46 [==============================] - 4s 83ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 6/60
# 46/46 [==============================] - 4s 84ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 7/60
# 46/46 [==============================] - 4s 84ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 8/60
# 46/46 [==============================] - 4s 80ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 9/60
# 46/46 [==============================] - 4s 79ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 10/60
# 46/46 [==============================] - 3s 73ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 11/60
# 46/46 [==============================] - 4s 77ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 12/60
# 46/46 [==============================] - 4s 85ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 13/60
# 46/46 [==============================] - 4s 91ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 14/60
# 46/46 [==============================] - 3s 76ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 15/60
# 46/46 [==============================] - 4s 81ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 16/60
# 46/46 [==============================] - 4s 82ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 17/60
# 46/46 [==============================] - 4s 82ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 18/60
# 46/46 [==============================] - 4s 84ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 19/60
# 46/46 [==============================] - 4s 81ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 20/60
# 46/46 [==============================] - 4s 78ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 21/60
# 46/46 [==============================] - 4s 77ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 22/60
# 46/46 [==============================] - 3s 74ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 23/60
# 46/46 [==============================] - 4s 81ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 24/60
# 46/46 [==============================] - 4s 83ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 25/60
# 46/46 [==============================] - 5s 104ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 26/60
# 46/46 [==============================] - 4s 78ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 27/60
# 46/46 [==============================] - 4s 76ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 28/60
# 46/46 [==============================] - 3s 74ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 29/60
# 46/46 [==============================] - 3s 75ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 30/60
# 46/46 [==============================] - 3s 76ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 31/60
# 46/46 [==============================] - 4s 77ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 32/60
# 46/46 [==============================] - 4s 77ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 33/60
# 46/46 [==============================] - 4s 78ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 34/60
# 46/46 [==============================] - 3s 74ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 35/60
# 46/46 [==============================] - 3s 74ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 36/60
# 46/46 [==============================] - 3s 72ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 37/60
# 46/46 [==============================] - 4s 82ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 38/60
# 46/46 [==============================] - 4s 90ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 39/60
# 46/46 [==============================] - 4s 89ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 40/60
# 46/46 [==============================] - 3s 75ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 41/60
# 46/46 [==============================] - 3s 75ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 42/60
# 46/46 [==============================] - 4s 77ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 43/60
# 46/46 [==============================] - 4s 76ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 44/60
# 46/46 [==============================] - 4s 77ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 45/60
# 46/46 [==============================] - 3s 75ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 46/60
# 46/46 [==============================] - 4s 78ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 47/60
# 46/46 [==============================] - 3s 74ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 48/60
# 46/46 [==============================] - 3s 73ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 49/60
# 46/46 [==============================] - 3s 74ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 50/60
# 46/46 [==============================] - 4s 77ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 51/60
# 46/46 [==============================] - 3s 73ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 52/60
# 46/46 [==============================] - 4s 78ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 53/60
# 46/46 [==============================] - 3s 75ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 54/60
# 46/46 [==============================] - 4s 77ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 55/60
# 46/46 [==============================] - 3s 73ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 56/60
# 46/46 [==============================] - 3s 73ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 57/60
# 46/46 [==============================] - 3s 75ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 58/60
# 46/46 [==============================] - 4s 82ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 59/60
# 46/46 [==============================] - 4s 79ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 60/60
# 46/46 [==============================] - 4s 76ms/step - loss: 0.0011 - mse: 0.0011

# %%
y_train.shape
# Out:
# (1464,)

# %%
np.isnan(X_train).sum()
# Out:
# 0

# %% [markdown]
# ###### Model Evaluation

# %%
wacRNNModel.predict(X_train).shape
# Out:
# 46/46 [==============================] - 1s 22ms/step
# (1464, 1)

# %%
### Test MAPE
predTest = wacRNNModel.predict(X_test)
predTest = [i[0] for i in predTest]
mapeTest = np.abs(predTest-y_test)/y_test

### Train MAPE
predTrain = wacRNNModel.predict(X_train)
predTrain = [i[0] for i in predTrain]
mapeTrain = np.abs(predTrain-y_train)/y_train 

print("Train MAPE: %s"%(mapeTrain.mean()))
print("Test MAPE: %s"%(mapeTest.mean()))
# Out:
# 12/12 [==============================] - 0s 22ms/step
# 46/46 [==============================] - 1s 22ms/step
# Train MAPE: 0.458994687411523
# Test MAPE: 0.26903339452902775

# %% [markdown]
# ### Saving model results to desk

# %%
mldName = '../models/cnn_model_%s'%(str(pd.Timestamp.now()).replace('.','_').replace(' ','_').replace(':','_'))+'.h5'

# %%
#wacRNNModel.save(mldName)

# %%
mapeTest.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 mapeTest.mean()
#
# NameError: name 'mapeTest' is not defined

# %%
### Saving model results
modelResults = pd.read_excel('../outputs/cnn_model_results.xlsx')
modelResults = pd.concat([modelResults, pd.DataFrame([{'name': mldName, 'test_mape': mapeTest.mean(), 'train_mape': mapeTrain.mean(), 'comment': '''
# create my NN model
wacRNNModel = Sequential()

embedding_size = 80
wacRNNModel.add(Embedding(len(vocab), embedding_size))
wacRNNModel.add(LSTM(20, return_sequences=True))
wacRNNModel.add(GlobalMaxPool1D())
wacRNNModel.add(Dense(10, activation='relu'))
wacRNNModel.add(Dense(5, activation='relu'))
wacRNNModel.add(Dense(1)) 

wacRNNModel.compile(loss='mse', 
              optimizer='adam', 
              metrics=['mse'])
wacRNNModel.summary()


epc = 40
wacRNNModel.fit(X_train, y_train, epochs=epc, batch_size=32)
'''}])])

modelResults.to_excel('../outputs/cnn_model_results.xlsx', index = False)

# %% [markdown]
# ### Loading saved model

# %%
wacRNNModel = keras.models.load_model('../models/cnn_model_2023-03-27_06_12_00_275007.h5')

# %%
### Test MAPE
predTest = wacRNNModel.predict(X_test)
predTest = [i[0] for i in predTest]
mapeTest = np.abs(predTest-y_test)/y_test
testResDf = pd.DataFrame({'Act': y_test, 'Pred': predTest})

### Train MAPE
predTrain = wacRNNModel.predict(X_train)
predTrain = [i[0] for i in predTrain]
mapeTrain = np.abs(predTrain-y_train)/y_train 
trainResDf = pd.DataFrame({'Act': y_train, 'Pred': predTrain})

print("Train MAPE: %s"%(mapeTrain.mean()))
print("Test MAPE: %s"%(mapeTest.mean()))
# Out:
# 12/12 [==============================] - 4s 29ms/step
# 46/46 [==============================] - 1s 22ms/step
# Train MAPE: 0.47959379932488294
# Test MAPE: 0.27574109391714174

# %%
len(wacRNNModel.predict(X_test))
# Out:
# 12/12 [==============================] - 1s 67ms/step
# 367

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, explained_variance_score

# %%
print("Train Mean Absolute Error: %s"%(mean_absolute_error(y_train, predTrain)))
print("Test Mean Absolute Error: %s"%(mean_absolute_error(y_test, predTest)))
# Out:
# Train Mean Absolute Error: 0.016464845618905728
# Test Mean Absolute Error: 0.021582938394297865

# %%
print("Train RMSE: %s"%(mean_squared_error(y_train, predTrain, squared=False)))
print("Test RMSE: %s"%(mean_squared_error(y_test, predTest, squared=False)))
# Out:
# Train RMSE: 0.0333352531953255
# Test RMSE: 0.04700553322262537

# %%
print("Train R2: %s"%(r2_score(y_train, predTrain)))
# Out:
# Train R2: 0.8479362025154518

# %% [markdown]
# ### Residual plot

# %%
trainResDf['Residual'] = trainResDf['Act'] - trainResDf['Pred']
testResDf['Residual'] = testResDf['Act'] - testResDf['Pred']

# %%
trainResDf.plot(x='Act', y='Pred', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='Act', ylabel='Pred'>

# %%
testResDf.plot(x='Act', y='Pred', kind = 'scatter', grid = True, color='grey', title = 'Test - Actual vs Predicted')
plt.show()

# %%
testResDf.plot(x='Act', y='Residual', kind = 'scatter', grid = True, color='grey', title = 'Test - Actual vs Residual', )
plt.show()
